# %% [markdown]
# <h1> Data Understanding (EDA + Manipulation) - Data Preparation - ML</h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/mahsa/Python_Data_Science/heart.csv")
data
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# 0            1.0                    2.0       150.0               0.0
# 1            0.0                    0.0       187.0               0.0
# 2            0.0                    2.0       172.0               0.0
# 3            0.0                    0.0       178.0               0.0
# 4            0.0                    0.0       163.0               1.0
# ..           ...                    ...         ...               ...
# 592          0.0                    0.0       134.0               1.0
# 593          0.0                    0.0       135.0               1.0
# 594          0.0                    0.0       118.0               1.0
# 595          0.0                    0.0       135.0               0.0
# 596          0.0                    0.0       122.0               0.0
#
#      depression   slope   ca  thal  c
# 0            2.3    3.0  0.0   6.0  0
# 1            3.5    3.0  0.0   3.0  0
# 2            1.4    1.0  0.0   3.0  0
# 3            0.8    1.0  0.0   3.0  0
# 4            0.6    1.0  0.0   3.0  0
# ..           ...    ...  ...   ... ..
# 592          2.0    2.0  NaN   NaN  1
# 593          2.0    2.0  NaN   NaN  1
# 594          3.0    2.0  NaN   NaN  1
# 595          0.0    NaN  NaN   NaN  1
# 596          2.0    2.0  NaN   NaN  1
#
# [597 rows x 14 columns]

# %%
data.head()
# Out:
#    Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                 63    1           1           145.0         233.0
# 1                 37    1           3           130.0         250.0
# 2                 41    0           2           130.0         204.0
# 3                 56    1           2           120.0         236.0
# 4                 57    0           4           120.0         354.0
#
#    blood sugar  electrocardiographic   heart rate  exercise induced  \
# 0          1.0                    2.0       150.0               0.0
# 1          0.0                    0.0       187.0               0.0
# 2          0.0                    2.0       172.0               0.0
# 3          0.0                    0.0       178.0               0.0
# 4          0.0                    0.0       163.0               1.0
#
#    depression   slope   ca  thal  c
# 0          2.3    3.0  0.0   6.0  0
# 1          3.5    3.0  0.0   3.0  0
# 2          1.4    1.0  0.0   3.0  0
# 3          0.8    1.0  0.0   3.0  0
# 4          0.6    1.0  0.0   3.0  0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597 entries, 0 to 596
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age (age in year)      597 non-null    int64
#  1   sex                    597 non-null    int64
#  2   chest pain             597 non-null    int64
#  3   blood pressure         596 non-null    float64
#  4   cholestoral            574 non-null    float64
#  5   blood sugar            589 non-null    float64
#  6   electrocardiographic   596 non-null    float64
#  7   heart rate             596 non-null    float64
#  8   exercise induced       596 non-null    float64
#  9   depression             597 non-null    float64
#  10  slope                  407 non-null    float64
#  11  ca                     303 non-null    float64
#  12  thal                   329 non-null    float64
#  13  c                      597 non-null    int64
# dtypes: float64(10), int64(4)
# memory usage: 65.4 KB

# %%
data.describe()
# Out:
#        Age (age in year)         sex  chest pain  blood pressure  \
# count         597.000000  597.000000  597.000000      596.000000
# mean           51.182580    0.701843    3.072027      132.129195
# std             9.074366    0.457833    0.965776       17.603812
# min            28.000000    0.000000    1.000000       92.000000
# 25%            44.000000    0.000000    2.000000      120.000000
# 50%            52.000000    1.000000    3.000000      130.000000
# 75%            58.000000    1.000000    4.000000      140.000000
# max            77.000000    1.000000    4.000000      200.000000
#
#        cholestoral   blood sugar  electrocardiographic   heart rate  \
# count    574.000000   589.000000             596.000000  596.000000
# mean     248.655052     0.110357               0.610738  144.456376
# std       59.784805     0.313600               0.869358   23.794282
# min       85.000000     0.000000               0.000000   71.000000
# 25%      211.000000     0.000000               0.000000  128.000000
# 50%      242.500000     0.000000               0.000000  146.000000
# 75%      278.750000     0.000000               2.000000  162.000000
# max      603.000000     1.000000               2.000000  202.000000
#
#        exercise induced  depression        slope          ca        thal  \
# count        596.000000   597.000000  407.000000  303.000000  329.000000
# mean           0.315436     0.816248    1.675676    0.693069    4.811550
# std            0.465080     1.067938    0.572758    1.049212    1.928854
# min            0.000000     0.000000    1.000000    0.000000    3.000000
# 25%            0.000000     0.000000    1.000000    0.000000    3.000000
# 50%            0.000000     0.200000    2.000000    0.000000    3.000000
# 75%            1.000000     1.500000    2.000000    1.000000    7.000000
# max            1.000000     6.200000    3.000000    9.000000    7.000000
#
#                 c
# count  597.000000
# mean     0.410385
# std      0.492316
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
data.isnull().sum()
# Out:
# Age (age in year)          0
# sex                        0
# chest pain                 0
# blood pressure             1
# cholestoral               23
# blood sugar                8
# electrocardiographic       1
# heart rate                 1
# exercise induced           1
# depression                 0
# slope                    190
# ca                       294
# thal                     268
# c                          0
# dtype: int64

# %%
# See unique values for each column
for col in data.columns:
    print(f"{col}: {data[col].unique()}\n")
# Out:
# Age (age in year): [63 37 41 56 57 44 52 54 48 49 64 58 50 66 43 69 59 42 61 40 71 51 65 53
#  46 45 39 47 62 34 35 29 55 60 67 68 74 76 70 38 36 32 31 28 30 33 77]
#
# sex: [1 0]
#
# chest pain: [1 3 2 4]
#
# blood pressure: [145. 130. 120. 140. 172. 150. 110. 135. 160. 105. 125. 142. 155. 104.
#  138. 128. 108. 134. 122. 115. 118. 100. 124.  94. 112. 102. 152. 101.
#  132. 148. 178. 129. 180. 136. 126. 106. 156. 170. 146. 113. 190.  98.
#   nan 174. 158. 192. 154.  92. 117. 144. 200. 123. 164. 165. 114.]
#
# cholestoral : [233. 250. 204. 236. 354. 192. 294. 263. 199. 168. 239. 275. 266. 211.
#  283. 219. 340. 226. 247. 234. 243. 302. 212. 175. 417. 197. 198. 177.
#  273. 213. 304. 232. 269. 360. 308. 245. 208. 264. 321. 325. 235. 257.
#  216. 256. 231. 141. 252. 201. 222. 260. 182. 303. 265. 309. 186. 203.
#  183. 220. 209. 258. 227. 261. 221. 205. 240. 318. 298. 564. 277. 214.
#  248. 255. 207. 223. 288. 160. 394. 315. 246. 244. 270. 195. 196. 254.
#  126. 313. 262. 215. 193. 271. 268. 267. 210. 295. 306. 178. 242. 180.
#  228. 149. 278. 253. 342. 157. 289.  nan 339. 237. 284. 184. 468. 188.
#  230. 259. 224. 194. 365. 202. 297. 225. 412. 218. 163. 167. 100. 238.
#  229. 307. 147.  85. 179. 129. 241. 276. 272. 161. 292. 249. 291. 320.
#  187. 287. 312. 251. 328. 280. 132. 217. 173. 281. 200. 326. 171. 274.
#  305. 347. 344. 358. 190. 166. 335. 330. 172. 185. 282. 322. 299. 300.
#  206. 466. 338. 156. 117. 286. 290. 341. 293. 409. 327. 311. 169. 529.
#  329. 392. 603. 355. 353. 164. 319. 176. 131. 518. 388. 279. 404. 285.
#  407. 174. 393. 331. 336. 491.]
#
# blood sugar: [ 1.  0. nan]
#
# electrocardiographic : [ 2.  0.  1. nan]
#
# heart rate: [150. 187. 172. 178. 163. 148. 153. 173. 162. 174. 160. 139. 171. 144.
#  158. 114. 151. 161. 179. 137. 157. 123. 152. 168. 140. 188. 125. 170.
#  165. 142. 180. 143. 182. 156. 115. 149. 146. 175. 186. 185. 159. 130.
#  190. 132. 147. 154. 202. 166. 164. 184. 122. 169. 138. 111. 145. 194.
#  131. 133. 155. 167. 192. 121.  96. 126. 105. 181. 116.  98. 120. 112.
#  118. 127. 134. 135. 110. 100. 106. 124. 176.  90. 136. 128. 129.  nan
#  109.  99. 177. 141.  88. 195.  87. 103. 108. 113.  97. 117.  71.  92.
#  102.  91.  95.  82.  94. 119.]
#
# exercise induced: [ 0.  1. nan]
#
# depression : [2.3 3.5 1.4 0.8 0.6 0.4 1.3 0.  0.5 1.6 1.2 0.2 1.8 1.  2.6 1.5 3.  2.4
#  0.1 1.9 4.2 1.1 2.  0.7 0.3 0.9 3.1 2.2 3.6 2.8 2.1 2.5 3.4 4.  3.2 6.2
#  5.6 2.9 3.8 4.4 5. ]
#
# slope: [ 3.  1.  2. nan]
#
# ca: [ 0.  2.  1.  3. nan  9.]
#
# thal: [ 6.  3.  7. nan]
#
# c: [0 1]

# %% [markdown]
# <p><h3>Adjusting Data Types</h3>
#
# In our dataset, all features are currently stored as either `int64` or `float64`.
# However, not all of them are truly continuous numerical variables.
#
# - **Numerical variables** → mean, median, std, correlations, histograms, boxplots.
#   Examples: `Age`, `blood pressure`, `cholestoral`, `heart rate`, `depression`.
#
# - **Categorical variables** → counts, proportions, cross-tabs, bar plots.
#   Examples: `sex`, `chest pain`, `blood sugar`, `electrocardiographic`, `exercise induced`,
#   `slope`, `ca`, `thal`, `c` (target).
#
# To ensure correct analysis, we convert categorical variables to `category` dtype.
# </p>

# %%
# Define categorical columns
categorical_cols = [
    "sex", "chest pain", "blood sugar", 
    "electrocardiographic ", "exercise induced", 
    "slope", "ca", "thal", "c"  # target
]

# Convert them to 'category' dtype
for col in categorical_cols:
    data[col] = data[col].astype("category")

# Quick check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597 entries, 0 to 596
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age (age in year)      597 non-null    int64
#  1   sex                    597 non-null    category
#  2   chest pain             597 non-null    category
#  3   blood pressure         596 non-null    float64
#  4   cholestoral            574 non-null    float64
#  5   blood sugar            589 non-null    category
#  6   electrocardiographic   596 non-null    category
#  7   heart rate             596 non-null    float64
#  8   exercise induced       596 non-null    category
#  9   depression             597 non-null    float64
#  10  slope                  407 non-null    category
#  11  ca                     303 non-null    category
#  12  thal                   329 non-null    category
#  13  c                      597 non-null    category
# dtypes: category(9), float64(4), int64(1)
# memory usage: 30.0 KB

# %%
data.rename(columns={"Age (age in year)":"age", "cholestoral ":"cholestoral", "depression ":"depression"}, inplace = True)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'chest pain', 'blood pressure', 'cholestoral',
#        'blood sugar', 'electrocardiographic ', 'heart rate',
#        'exercise induced', 'depression', 'slope', 'ca', 'thal', 'c'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                 count        mean        std   min    25%    50%     75%  \
# age             597.0   51.182580   9.074366  28.0   44.0   52.0   58.00
# blood pressure  596.0  132.129195  17.603812  92.0  120.0  130.0  140.00
# cholestoral     574.0  248.655052  59.784805  85.0  211.0  242.5  278.75
# heart rate      596.0  144.456376  23.794282  71.0  128.0  146.0  162.00
# depression      597.0    0.816248   1.067938   0.0    0.0    0.2    1.50
#
#                   max
# age              77.0
# blood pressure  200.0
# cholestoral     603.0
# heart rate      202.0
# depression        6.2

# %% [markdown]
# <h3>Potential outliers:</h3>
# Blood pressure (max=200), cholesterol (max=603), heart rate (max=202).
# <h3>Skewed distributions:</h3>
# Depression is heavily skewed; cholesterol might be slightly skewed right.

# %%
data.describe(include='category').T
# Out:
#                        count  unique  top   freq
# sex                    597.0     2.0  1.0  419.0
# chest pain             597.0     4.0  4.0  267.0
# blood sugar            589.0     2.0  0.0  524.0
# electrocardiographic   596.0     3.0  0.0  386.0
# exercise induced       596.0     2.0  0.0  408.0
# slope                  407.0     3.0  2.0  231.0
# ca                     303.0     5.0  0.0  179.0
# thal                   329.0     3.0  3.0  173.0
# c                      597.0     2.0  0.0  352.0

# %% [markdown]
# <p>Binary features: sex, blood sugar, exercise induced, c → can encode as 0/1 directly.</p>
# <p>Categorical features with multiple classes: chest pain, slope, ca, thal → may need one-hot encoding late</p>

# %%
continuous_features = ['age', 'blood pressure', 'cholestoral', 'heart rate', 'depression']

# %%
# Select continuous features
data_continuous = data[continuous_features]

# Create subplots dynamically
n_cols = 3
n_rows = int(np.ceil(len(data_continuous.columns) / n_cols))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 8))

axes = axes.flatten()  # Flatten so you can loop easily

for i, col in enumerate(data_continuous.columns):
    ax = axes[i]
    col_data = data_continuous[col].dropna()

    # Plot histogram with KDE
    sns.histplot(col_data, bins='auto', kde=True, color='red', alpha=0.6, ax=ax)

    # Axis labels and grid
    ax.set_title(col, fontsize=12)
    ax.set_xlabel('')
    ax.set_ylabel('Count', fontsize=10)
    ax.grid(True, color='lightgrey', alpha=0.5)

    # Show mean and std inside plot
    mean, std = col_data.mean(), col_data.std()
    textstr = f'μ = {mean:.2f}\nσ = {std:.2f}'
    ax.text(0.95, 0.9, textstr, transform=ax.transAxes, fontsize=10,
            color='white', ha='right', va='top',
            bbox=dict(boxstyle='round', facecolor='#ff826e', edgecolor='white'))

# Turn off unused axes (if any)
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.suptitle('Distribution of Continuous Variables', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
n_cols = 3
n_rows = (len(continuous_features) + n_cols - 1) // n_cols
plt.figure(figsize=(n_cols * 5, n_rows * 4))

# Loop through columns and plot
for idx, column_name in enumerate(continuous_features, 1):
    plt.subplot(n_rows, n_cols, idx)
    sns.boxplot(y=data[column_name])
    plt.title(f'Boxplot of {column_name}')
plt.tight_layout()

plt.show()

# %% [markdown]
# <h4>Shape of distributions:</h4>
# Age and heart rate: roughly normal.
# Blood pressure, cholesterol, and depression: right-skewed (most values are low, with a few high extremes).
# <p>Outliers:</p>
# Blood pressure, Cholesterol and depression: potential outliers observed.

# %%
#correlation matrix
corr_matrix = data_continuous.corr()

plt.figure(figsize=(8, 6))

sns.heatmap(corr_matrix, 
            annot=True,        # Show correlation values
            fmt=".2f",         # 2 decimal places
            cmap='coolwarm',   # Color palette
            cbar=True,         # Show color bar
            square=True,       # Make squares
            linewidths=0.5)    # Lines between cells

plt.title('Correlation Heatmap of Continuous Features', fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# No numeric feature is strongly correlated (>0.7) with another, suggesting low multicollinearity. Age shows weak positive correlation with blood pressure.

# %%
categorical_features = data.columns.difference(continuous_features)
data_categorical = data[categorical_features]

# %%
# Select categorical features
data_categorical = data[categorical_features]

# Dynamically define subplot grid
n_cols = 2
n_rows = int(np.ceil(len(categorical_features) / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, n_rows * 3))
axes = axes.flatten()

# Loop over categorical columns
for i, col in enumerate(categorical_features):
    ax = axes[i]
    value_counts = data[col].value_counts(normalize=True).mul(100).sort_values()

    # Plot horizontal bar chart
    value_counts.plot(kind='barh', ax=ax, color='green', width=0.6)

    # Add percentage labels
    for index, value in enumerate(value_counts):
        ax.text(value + 1, index, f'{value:.1f}%', va='center', fontsize=10, fontweight='bold')

    ax.set_xlim(0, value_counts.max() + 10)
    ax.set_title(col, fontsize=13)
    ax.set_xlabel('Frequency (%)')
    ax.set_ylabel('')
    ax.grid(axis='x', color='lightgrey', alpha=0.5)

# Hide unused subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.suptitle('Distribution of Categorical Variables', fontsize=18)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# <h4>Categorical Features:</h4>
# c (target variable): 59% without heart disease, 41% with heart disease → reasonably balanced.
# ca (number of major vessels): contains ~3% of values = 9 → likely a data entry error or outlier that needs attention.
# Dominant categories: sex=1 is 70% of patients, blood sugar = 1 is 89%

# %%
# Set style and color palette
sns.set_style('whitegrid')
sns.set_palette(['#FF91A4', 'red'])

# Create the subplot grid dynamically
fig, axes = plt.subplots(len(continuous_features), 2, figsize=(8, len(continuous_features) * 2),
                         gridspec_kw={'width_ratios': [1, 2]})

# Ensure axes is always 2D even for a single feature
if len(continuous_features) == 1:
    axes = [axes]

# Loop through each continuous feature
for i, col in enumerate(continuous_features):
    ax_bar, ax_kde = axes[i]

    # --- Barplot: Mean of feature by target ---
    bar = sns.barplot(data=data, x="c", y=col, ax=ax_bar)
    bar.set_title(f'Mean {col} by Target', fontsize=12)
    bar.set_xlabel('')
    bar.set_ylabel('Mean Value')
    
    # Add mean value labels
    for container in bar.containers:
        bar.bar_label(container, fmt='%.2f', fontsize=10, padding=3)

    # --- KDE plots: Distribution by target ---
    sns.kdeplot(data=data, x=col, hue="c", fill=True, linewidth=2, ax=ax_kde)
    ax_kde.set_title(f'{col} Distribution by Target', fontsize=12)
    ax_kde.set_yticks([])
    ax_kde.legend(title='Target', loc='upper right')

# --- Final layout adjustments ---
plt.suptitle('Continuous Features vs Target Distribution', fontsize=18, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/8v/j04s7d697pbchpncxsv_q5zw0000gn/T/ipykernel_1849/476137645.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_kde.legend(title='Target', loc='upper right')
# /var/folders/8v/j04s7d697pbchpncxsv_q5zw0000gn/T/ipykernel_1849/476137645.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_kde.legend(title='Target', loc='upper right')
# /var/folders/8v/j04s7d697pbchpncxsv_q5zw0000gn/T/ipykernel_1849/476137645.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_kde.legend(title='Target', loc='upper right')
# /var/folders/8v/j04s7d697pbchpncxsv_q5zw0000gn/T/ipykernel_1849/476137645.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_kde.legend(title='Target', loc='upper right')
# /var/folders/8v/j04s7d697pbchpncxsv_q5zw0000gn/T/ipykernel_1849/476137645.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_kde.legend(title='Target', loc='upper right')

# %% [markdown]
# There is a high correlation between variables and target.

# %%
categorical_features = [feature for feature in categorical_features if feature != 'c']

# %%
from matplotlib.colors import ListedColormap

# Define color palette and layout
cmp = ListedColormap(['#F2003C', '#FDBCB4'])
n_cols = 4
n_rows = int(np.ceil(len(categorical_features) / n_cols))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 3))
axes = axes.flatten()

for i, col in enumerate(categorical_features):
    ax = axes[i]
    
    # Cross tab: counts and proportions
    cross_tab = pd.crosstab(index=data[col], columns=data['c'])
    cross_tab_prop = pd.crosstab(index=data[col], columns=data['c'], normalize='index')

    # Plot normalized stacked bars
    cross_tab_prop.plot(kind='bar', stacked=True, width=0.8, colormap=cmp,
                        ax=ax, legend=False, ylabel='Proportion')

    # Add count and % labels
    for idx, cat in enumerate(cross_tab.index):
        cumulative = 0
        for c_val in cross_tab.columns:
            proportion = cross_tab_prop.loc[cat, c_val]
            count = cross_tab.loc[cat, c_val]
            ax.text(idx, cumulative + proportion / 2, f'{count}\n({proportion*100:.1f}%)',
                    ha='center', va='center', fontsize=8, fontweight='bold', color='black')
            cumulative += proportion

    # Style adjustments
    ax.set_title(col, fontsize=11, pad=8)
    ax.set_ylim(0, 1.1)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
    ax.grid(axis='y', color='lightgrey', alpha=0.4)

# Hide unused axes
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

# Add legend once at the bottom
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, ['0', '1'], title='Target (c)', loc='lower center', ncol=2, fontsize=10)

plt.suptitle('Categorical Features vs Target Stacked Barplots', fontsize=18, y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# <h4>Categorical Features vs Target (c)</h4>
# <p>ca (major vessels): 75% of people with ca=3 have heart disease (c=1).</p>
# <p>chest pain: 70% of people with high chest pain have heart disease.</p>
# <p>exercise induced: 77% of people with exercise-induced angina have heart disease.</p>
# <p>slope: 70% of people with slope=2 have heart disease.</p>
# <p>thal: 75% of people with thal=7 have heart disease.</p>

# %% [markdown]
# <h4>EDA Summary / Conclusion</h4>
# <p>Categorical issues: ca contains ~3% noisy/outlier values (9) that need attention.</p>
# <p>Shape of numeric distributions:
# Age and heart rate → roughly normal.
# Blood pressure, cholesterol, depression → right-skewed.</p>
# <p>Outliers: Blood pressure, cholesterol, depression, and possibly heart rate show potential outliers.</p>

# %% [markdown]
# <h3>Outliers Detection</h3>
# <p>1. Statistics - IQR</p>

# %%
# Initialize an empty set to store all outlier row indices
all_outlier_indices = set()

# Loop over numeric columns
for col in data.select_dtypes(include='number').columns:
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    IQR = q3 - q1
    
    # Find outliers in this column
    col_outliers = data[(data[col] < q1 - 1.5 * IQR) | (data[col] > q3 + 1.5 * IQR)].index
    
    # Add these row indices to the set
    all_outlier_indices.update(col_outliers)

# Convert set to list
all_outlier_indices = list(all_outlier_indices)

# Create a DataFrame with all outlier rows
outliers_df = data.loc[all_outlier_indices]

outliers_df
# Out:
#      age sex chest pain  blood pressure  cholestoral blood sugar  \
# 513   68   1          3           180.0        274.0         1.0
# 514   62   0          4           160.0        164.0         0.0
# 387   54   1          2           192.0        283.0         0.0
# 8     52   1          3           172.0        199.0         1.0
# 521   56   0          4           200.0        288.0         1.0
# 520   55   1          4           140.0        217.0         0.0
# 527   51   1          4           140.0        298.0         0.0
# 532   66   0          4           178.0        228.0         1.0
# 283   46   1          4           180.0        280.0         0.0
# 28    65   0          3           140.0        417.0         1.0
# 545   53   1          3           145.0        518.0         0.0
# 421   40   1          4           120.0        466.0         NaN
# 549   52   1          4           160.0        246.0         0.0
# 553   56   1          4           170.0        388.0         0.0
# 560   52   1          4           140.0        404.0         0.0
# 561   53   1          4           180.0        285.0         0.0
# 183   53   0          2           113.0        468.0         NaN
# 573   63   0          4           150.0        407.0         0.0
# 579   38   1          1           120.0        231.0         0.0
# 324   55   0          2           130.0        394.0         0.0
# 581   58   1          4           114.0        318.0         0.0
# 585   58   0          2           180.0        393.0         0.0
# 460   56   0          4           134.0        409.0         0.0
# 591   50   1          4           140.0        231.0         0.0
# 336   45   0          2           180.0          NaN         0.0
# 337   59   1          3           180.0        213.0         0.0
# 338   57   0          4           180.0        347.0         0.0
# 465   55   0          4           180.0        327.0         0.0
# 210   44   1          4           150.0        412.0         0.0
# 85    67   0          3           115.0        564.0         0.0
# 595   44   1          4           135.0        491.0         0.0
# 215   52   1          2           140.0        100.0         0.0
# 468   67   1          4           120.0        237.0         0.0
# 478   63   1          4           140.0        187.0         0.0
# 96    62   0          4           140.0        394.0         0.0
# 227   56   1          4           120.0         85.0         0.0
# 483   32   1          4           118.0        529.0         0.0
# 101   59   1          1           178.0        270.0         0.0
# 488   40   0          4           150.0        392.0         0.0
# 234   39   1          2           190.0        241.0         0.0
# 491   54   1          4           130.0        603.0         1.0
# 110   64   0          4           180.0        325.0         0.0
# 499   54   1          4           200.0        198.0         0.0
# 383   59   0          4           174.0        249.0         0.0
#
#     electrocardiographic   heart rate exercise induced  depression slope   ca  \
# 513                   2.0       150.0              1.0         1.6   2.0  0.0
# 514                   2.0       145.0              0.0         6.2   3.0  3.0
# 387                   2.0       195.0              0.0         0.0   1.0  1.0
# 8                     0.0       162.0              0.0         0.5   1.0  0.0
# 521                   2.0       133.0              1.0         4.0   3.0  2.0
# 520                   0.0       111.0              1.0         5.6   3.0  0.0
# 527                   0.0       122.0              1.0         4.2   2.0  3.0
# 532                   0.0       165.0              1.0         1.0   2.0  2.0
# 283                   1.0       120.0              0.0         0.0   NaN  NaN
# 28                    2.0       157.0              0.0         0.8   1.0  1.0
# 545                   0.0       130.0              0.0         0.0   NaN  NaN
# 421                   0.0       152.0              1.0         1.0   2.0  NaN
# 549                   1.0        82.0              1.0         4.0   2.0  NaN
# 553                   1.0       122.0              1.0         2.0   2.0  NaN
# 560                   0.0       124.0              1.0         2.0   2.0  NaN
# 561                   1.0       120.0              1.0         1.5   2.0  NaN
# 183                   0.0       127.0              0.0         0.0   NaN  NaN
# 573                   2.0       154.0              0.0         4.0   2.0  3.0
# 579                   0.0       182.0              1.0         3.8   2.0  0.0
# 324                   2.0       150.0              0.0         0.0   NaN  NaN
# 581                   1.0       140.0              0.0         4.4   3.0  3.0
# 585                   0.0       110.0              1.0         1.0   2.0  NaN
# 460                   2.0       150.0              1.0         1.9   2.0  2.0
# 591                   1.0       140.0              1.0         5.0   2.0  NaN
# 336                   0.0       180.0              0.0         0.0   NaN  NaN
# 337                   0.0       100.0              0.0         0.0   NaN  NaN
# 338                   1.0       126.0              1.0         0.8   2.0  NaN
# 465                   1.0       117.0              1.0         3.4   2.0  0.0
# 210                   0.0       170.0              0.0         0.0   NaN  NaN
# 85                    2.0       160.0              0.0         1.6   2.0  0.0
# 595                   0.0       135.0              0.0         0.0   NaN  NaN
# 215                   0.0       138.0              1.0         0.0   NaN  NaN
# 468                   0.0        71.0              0.0         1.0   2.0  0.0
# 478                   2.0       144.0              1.0         4.0   1.0  2.0
# 96                    2.0       157.0              0.0         1.2   2.0  0.0
# 227                   0.0       140.0              0.0         0.0   NaN  NaN
# 483                   0.0       130.0              0.0         0.0   NaN  NaN
# 101                   2.0       145.0              0.0         4.2   3.0  0.0
# 488                   0.0       130.0              0.0         2.0   2.0  NaN
# 234                   0.0       106.0              0.0         0.0   NaN  NaN
# 491                   0.0       125.0              1.0         1.0   2.0  NaN
# 110                   0.0       154.0              1.0         0.0   1.0  0.0
# 499                   0.0       142.0              1.0         2.0   2.0  NaN
# 383                   0.0       143.0              1.0         0.0   2.0  0.0
#
#     thal  c
# 513  7.0  1
# 514  7.0  1
# 387  7.0  1
# 8    7.0  0
# 521  7.0  1
# 520  7.0  1
# 527  7.0  1
# 532  7.0  1
# 283  NaN  0
# 28   3.0  0
# 545  NaN  1
# 421  6.0  1
# 549  NaN  1
# 553  NaN  1
# 560  NaN  1
# 561  NaN  1
# 183  NaN  0
# 573  7.0  1
# 579  7.0  1
# 324  NaN  0
# 581  6.0  1
# 585  7.0  1
# 460  7.0  1
# 591  NaN  1
# 336  NaN  0
# 337  NaN  0
# 338  NaN  0
# 465  3.0  1
# 210  NaN  0
# 85   7.0  0
# 595  NaN  1
# 215  NaN  0
# 468  3.0  1
# 478  7.0  1
# 96   3.0  0
# 227  NaN  0
# 483  NaN  1
# 101  7.0  0
# 488  6.0  1
# 234  NaN  0
# 491  NaN  1
# 110  3.0  0
# 499  NaN  1
# 383  3.0  1

# %% [markdown]
# <p>2. Statistics - Z-Score</p>

# %%
lst = []
for i in data.select_dtypes(include='number').columns:
    outliers = data[((data[i] - data[i].mean())/data[i].std()).abs()>3]
    if not outliers.empty:
        lst.append({'column name': i, 
                 'outliers': outliers})
lst
# Out:
# [{'column name': 'blood pressure',
#   'outliers':      age sex chest pain  blood pressure  cholestoral blood sugar  \
#   234   39   1          2           190.0        241.0         0.0
#   387   54   1          2           192.0        283.0         0.0
#   499   54   1          4           200.0        198.0         0.0
#   521   56   0          4           200.0        288.0         1.0
#
#       electrocardiographic   heart rate exercise induced  depression slope   ca  \
#   234                   0.0       106.0              0.0         0.0   NaN  NaN
#   387                   2.0       195.0              0.0         0.0   1.0  1.0
#   499                   0.0       142.0              1.0         2.0   2.0  NaN
#   521                   2.0       133.0              1.0         4.0   3.0  2.0
#
#       thal  c
#   234  NaN  0
#   387  7.0  1
#   499  NaN  1
#   521  7.0  1  },
#  {'column name': 'cholestoral',
#   'outliers':      age sex chest pain  blood pressure  cholestoral blood sugar  \
#   85    67   0          3           115.0        564.0         0.0
#   183   53   0          2           113.0        468.0         NaN
#   421   40   1          4           120.0        466.0         NaN
#   483   32   1          4           118.0        529.0         0.0
#   491   54   1          4           130.0        603.0         1.0
#   545   53   1          3           145.0        518.0         0.0
#   595   44   1          4           135.0        491.0         0.0
#
#       electrocardiographic   heart rate exercise induced  depression slope   ca  \
#   85                    2.0       160.0              0.0         1.6   2.0  0.0
#   183                   0.0       127.0              0.0         0.0   NaN  NaN
#   421                   0.0       152.0              1.0         1.0   2.0  NaN
#   483                   0.0       130.0              0.0         0.0   NaN  NaN
#   491                   0.0       125.0              1.0         1.0   2.0  NaN
#   545                   0.0       130.0              0.0         0.0   NaN  NaN
#   595                   0.0       135.0              0.0         0.0   NaN  NaN
#
#       thal  c
#   85   7.0  0
#   183  NaN  0
#   421  6.0  1
#   483  NaN  1
#   491  NaN  1
#   545  NaN  1
#   595  NaN  1  },
#  {'column name': 'heart rate',
#   'outliers':      age sex chest pain  blood pressure  cholestoral blood sugar  \
#   468   67   1          4           120.0        237.0         0.0
#
#       electrocardiographic   heart rate exercise induced  depression slope   ca  \
#   468                   0.0        71.0              0.0         1.0   2.0  0.0
#
#       thal  c
#   468  3.0  1  },
#  {'column name': 'depression',
#   'outliers':      age sex chest pain  blood pressure  cholestoral blood sugar  \
#   101   59   1          1           178.0        270.0         0.0
#   514   62   0          4           160.0        164.0         0.0
#   520   55   1          4           140.0        217.0         0.0
#   527   51   1          4           140.0        298.0         0.0
#   581   58   1          4           114.0        318.0         0.0
#   591   50   1          4           140.0        231.0         0.0
#
#       electrocardiographic   heart rate exercise induced  depression slope   ca  \
#   101                   2.0       145.0              0.0         4.2   3.0  0.0
#   514                   2.0       145.0              0.0         6.2   3.0  3.0
#   520                   0.0       111.0              1.0         5.6   3.0  0.0
#   527                   0.0       122.0              1.0         4.2   2.0  3.0
#   581                   1.0       140.0              0.0         4.4   3.0  3.0
#   591                   1.0       140.0              1.0         5.0   2.0  NaN
#
#       thal  c
#   101  7.0  0
#   514  7.0  1
#   520  7.0  1
#   527  7.0  1
#   581  6.0  1
#   591  NaN  1  }]

# %% [markdown]
# <h4>Since the data is skewed for blood pressure','cholestoral', 'heart rate','depression', IQR is more robust than Z-score.</h4>

# %%
clean_data = data.copy()  # Keep original, work on a copy

# %%
clean_data = clean_data.drop(index=outliers_df.index)

# %%
clean_data
# Out:
#      age sex chest pain  blood pressure  cholestoral blood sugar  \
# 0     63   1          1           145.0        233.0         1.0
# 1     37   1          3           130.0        250.0         0.0
# 2     41   0          2           130.0        204.0         0.0
# 3     56   1          2           120.0        236.0         0.0
# 4     57   0          4           120.0        354.0         0.0
# ..   ...  ..        ...             ...          ...         ...
# 590   49   1          4           128.0        212.0         0.0
# 592   52   1          4           140.0        266.0         0.0
# 593   43   1          4           140.0        288.0         0.0
# 594   41   1          4           120.0        336.0         0.0
# 596   49   1          4           150.0        222.0         0.0
#
#     electrocardiographic   heart rate exercise induced  depression slope   ca  \
# 0                     2.0       150.0              0.0         2.3   3.0  0.0
# 1                     0.0       187.0              0.0         3.5   3.0  0.0
# 2                     2.0       172.0              0.0         1.4   1.0  0.0
# 3                     0.0       178.0              0.0         0.8   1.0  0.0
# 4                     0.0       163.0              1.0         0.6   1.0  0.0
# ..                    ...         ...              ...         ...   ...  ...
# 590                   0.0        96.0              1.0         0.0   NaN  NaN
# 592                   0.0       134.0              1.0         2.0   2.0  NaN
# 593                   0.0       135.0              1.0         2.0   2.0  NaN
# 594                   0.0       118.0              1.0         3.0   2.0  NaN
# 596                   0.0       122.0              0.0         2.0   2.0  NaN
#
#     thal  c
# 0    6.0  0
# 1    3.0  0
# 2    3.0  0
# 3    3.0  0
# 4    3.0  0
# ..   ... ..
# 590  NaN  1
# 592  NaN  1
# 593  NaN  1
# 594  NaN  1
# 596  NaN  1
#
# [553 rows x 14 columns]

# %% [markdown]
# <h3>Handling Missing values</h3>

# %%
clean_data.isnull().sum()
# Out:
# age                        0
# sex                        0
# chest pain                 0
# blood pressure             1
# cholestoral               22
# blood sugar                6
# electrocardiographic       1
# heart rate                 1
# exercise induced           1
# depression                 0
# slope                    178
# ca                       271
# thal                     248
# c                          0
# dtype: int64

# %%
data_ = clean_data.dropna(thresh = 500, axis = 1)

# %%
data_.isnull().sum()
# Out:
# age                       0
# sex                       0
# chest pain                0
# blood pressure            1
# cholestoral              22
# blood sugar               6
# electrocardiographic      1
# heart rate                1
# exercise induced          1
# depression                0
# c                         0
# dtype: int64

# %%
# Numeric: fill with median
for col in data_.select_dtypes(include=['float64','int64']).columns:
    data_[col] = data_[col].fillna(data_[col].median())

# Categorical: fill with mode
for col in data_.select_dtypes(include=['category']).columns:
        data_[col] = data_[col].fillna(data_[col].mode()[0])
# Out:
# /var/folders/8v/j04s7d697pbchpncxsv_q5zw0000gn/T/ipykernel_1849/4150532490.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_[col] = data_[col].fillna(data_[col].median())
# /var/folders/8v/j04s7d697pbchpncxsv_q5zw0000gn/T/ipykernel_1849/4150532490.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_[col] = data_[col].fillna(data_[col].mode()[0])

# %%
data_.isnull().sum()
# Out:
# age                      0
# sex                      0
# chest pain               0
# blood pressure           0
# cholestoral              0
# blood sugar              0
# electrocardiographic     0
# heart rate               0
# exercise induced         0
# depression               0
# c                        0
# dtype: int64

# %%
data_.head()
# Out:
#    age sex chest pain  blood pressure  cholestoral blood sugar  \
# 0   63   1          1           145.0        233.0         1.0
# 1   37   1          3           130.0        250.0         0.0
# 2   41   0          2           130.0        204.0         0.0
# 3   56   1          2           120.0        236.0         0.0
# 4   57   0          4           120.0        354.0         0.0
#
#   electrocardiographic   heart rate exercise induced  depression  c
# 0                   2.0       150.0              0.0         2.3  0
# 1                   0.0       187.0              0.0         3.5  0
# 2                   2.0       172.0              0.0         1.4  0
# 3                   0.0       178.0              0.0         0.8  0
# 4                   0.0       163.0              1.0         0.6  0

# %% [markdown]
# <p> In the classic UCI Heart Disease dataset, the chest pain variable (cp) has these codes:
# 0 = Typical angina
# 1 = Atypical angina
# 2 = Non-anginal pain
# 3 = Asymptomatic
# 👉 So these are categories of chest pain type, not levels of severity.</p>
#
# In the UCI Heart dataset, the column restecg (resting electrocardiog>raphic results) is coded as:
# 0 = Normal
# 1 = Having ST-T wave abnormality
# 2 = Showing probable or definite left ventricular hypertrophy

# %%
data_encoded = pd.get_dummies(data_, columns=['electrocardiographic '], prefix='ecg', dtype=int)

# %%
data_encoded
# Out:
#      age sex chest pain  blood pressure  cholestoral blood sugar  heart rate  \
# 0     63   1          1           145.0        233.0         1.0       150.0
# 1     37   1          3           130.0        250.0         0.0       187.0
# 2     41   0          2           130.0        204.0         0.0       172.0
# 3     56   1          2           120.0        236.0         0.0       178.0
# 4     57   0          4           120.0        354.0         0.0       163.0
# ..   ...  ..        ...             ...          ...         ...         ...
# 590   49   1          4           128.0        212.0         0.0        96.0
# 592   52   1          4           140.0        266.0         0.0       134.0
# 593   43   1          4           140.0        288.0         0.0       135.0
# 594   41   1          4           120.0        336.0         0.0       118.0
# 596   49   1          4           150.0        222.0         0.0       122.0
#
#     exercise induced  depression  c  ecg_0.0  ecg_1.0  ecg_2.0
# 0                0.0         2.3  0        0        0        1
# 1                0.0         3.5  0        1        0        0
# 2                0.0         1.4  0        0        0        1
# 3                0.0         0.8  0        1        0        0
# 4                1.0         0.6  0        1        0        0
# ..               ...         ... ..      ...      ...      ...
# 590              1.0         0.0  1        1        0        0
# 592              1.0         2.0  1        1        0        0
# 593              1.0         2.0  1        1        0        0
# 594              1.0         3.0  1        1        0        0
# 596              0.0         2.0  1        1        0        0
#
# [553 rows x 13 columns]

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553 entries, 0 to 596
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               553 non-null    int64
#  1   sex               553 non-null    category
#  2   chest pain        553 non-null    category
#  3   blood pressure    553 non-null    float64
#  4   cholestoral       553 non-null    float64
#  5   blood sugar       553 non-null    category
#  6   heart rate        553 non-null    float64
#  7   exercise induced  553 non-null    category
#  8   depression        553 non-null    float64
#  9   c                 553 non-null    category
#  10  ecg_0.0           553 non-null    int64
#  11  ecg_1.0           553 non-null    int64
#  12  ecg_2.0           553 non-null    int64
# dtypes: category(5), float64(4), int64(4)
# memory usage: 42.3 KB

# %%
# See unique values for each column
for col in data_encoded.columns:
    print(f"{col}: {data_encoded[col].unique()}\n")
# Out:
# age: [63 37 41 56 57 44 54 48 49 64 58 50 66 43 69 59 42 61 40 71 51 53 65 46
#  45 39 52 47 62 34 35 29 55 60 68 67 74 76 70 38 36 32 31 28 30 33 77]
#
# sex: [1, 0]
# Categories (2, int64): [0, 1]
#
# chest pain: [1, 3, 2, 4]
# Categories (4, int64): [1, 2, 3, 4]
#
# blood pressure: [145. 130. 120. 140. 150. 110. 135. 160. 105. 125. 142. 155. 104. 138.
#  128. 108. 134. 122. 115. 118. 100. 124.  94. 112. 102. 152. 101. 132.
#  148. 129. 136. 126. 106. 156. 170. 146.  98. 158. 154.  92. 117. 144.
#  123. 164. 165.]
#
# cholestoral: [233. 250. 204. 236. 354. 192. 294. 263. 168. 239. 275. 266. 211. 283.
#  219. 340. 226. 247. 234. 243. 199. 302. 212. 175. 197. 198. 177. 273.
#  213. 304. 232. 269. 360. 308. 245. 208. 264. 321. 325. 235. 257. 216.
#  256. 231. 141. 252. 201. 222. 260. 182. 303. 265. 309. 186. 203. 183.
#  220. 209. 258. 227. 261. 221. 205. 240. 318. 298. 277. 214. 248. 255.
#  207. 223. 288. 160. 315. 246. 244. 195. 196. 254. 126. 313. 262. 215.
#  193. 271. 268. 267. 210. 295. 306. 178. 242. 180. 228. 149. 278. 253.
#  342. 157. 289. 339. 237. 284. 184. 188. 230. 259. 224. 194. 365. 202.
#  297. 225. 218. 163. 167. 238. 229. 307. 147. 179. 129. 276. 272. 161.
#  292. 249. 270. 291. 320. 187. 287. 312. 251. 328. 132. 217. 173. 281.
#  200. 326. 171. 274. 305. 344. 358. 190. 166. 335. 330. 172. 185. 282.
#  322. 299. 300. 241. 206. 338. 156. 117. 286. 290. 341. 293. 311. 169.
#  329. 280. 355. 353. 319. 176. 131. 164. 279. 174. 331. 336.]
#
# blood sugar: [1.0, 0.0]
# Categories (2, float64): [0.0, 1.0]
#
# heart rate: [150. 187. 172. 178. 163. 148. 153. 173. 174. 160. 139. 171. 144. 162.
#  158. 114. 151. 161. 179. 137. 157. 123. 152. 168. 140. 188. 125. 170.
#  165. 142. 180. 143. 182. 156. 115. 149. 146. 175. 186. 185. 159. 130.
#  190. 132. 147. 154. 202. 166. 164. 184. 122. 169. 138. 111. 194. 131.
#  133. 155. 167. 192. 121.  96. 126. 105. 181. 116.  98. 120. 145. 112.
#  118. 134. 135. 110. 100. 124. 176.  90. 136. 128. 129. 109.  99. 177.
#  141.  88.  87. 103. 108. 113.  97. 127. 106.  92. 102.  91.  95.  94.
#  119.]
#
# exercise induced: [0.0, 1.0]
# Categories (2, float64): [0.0, 1.0]
#
# depression: [2.3 3.5 1.4 0.8 0.6 0.4 1.3 0.  1.6 1.2 0.2 1.8 1.  2.6 1.5 0.5 3.  2.4
#  0.1 1.9 1.1 2.  0.7 0.3 0.9 3.1 2.2 3.6 2.8 2.1 2.5 3.4 3.2 2.9]
#
# c: [0, 1]
# Categories (2, int64): [0, 1]
#
# ecg_0.0: [0 1]
#
# ecg_1.0: [0 1]
#
# ecg_2.0: [1 0]

# %% [markdown]
# ### Feature Scaling & Validation Strategy
#
# We apply two approaches:
#
# 1. **Train-Test Split**
#    - Drop the target column `c`.
#    - Split the dataset into training (80%) and test (20%).
#    - Normalize the training set (fit the scaler) and apply the same transformation to the test set.
#    - Train ML models on the scaled training data and evaluate on the test data.
#
# 2. **Cross-Validation**
#    - Drop the target column `c`.
#    - Use cross-validation for more reliable performance estimation.
#    - Scaling is applied inside each fold (using `Pipeline`) so that the scaler is fitted only on training folds and applied to validation folds.
#    - This avoids data leakage and ensures fair evaluation.

# %%
from sklearn.model_selection import train_test_split

X = data_encoded.drop('c', axis=1)   # features
y = data_encoded['c']                # target

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)
#stratify=y

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Initialize scaler
sc = MinMaxScaler()

# Fit on train only
X_train_scaled = pd.DataFrame(sc.fit_transform(X_train), columns=X_train.columns, index=X_train.index)

# Transform test with the same scaler
X_test_scaled = pd.DataFrame(sc.transform(X_test), columns=X_test.columns, index=X_test.index)

# %%
X_train_scaled2 = X_train_scaled.drop_duplicates()

# %%
print(X_train_scaled.shape, X_train_scaled2.shape)
# Out:
# (442, 12) (442, 12)

# %%
X_train_scaled
# Out:
#           age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 455  0.666667  1.0    1.000000        0.342105     0.560669          0.0
# 546  0.250000  1.0    1.000000        0.473684     0.192469          0.0
# 495  0.208333  1.0    1.000000        0.210526     0.644351          0.0
# 577  1.000000  1.0    1.000000        0.407895     0.744770          0.0
# 365  0.354167  1.0    0.666667        0.736842     0.439331          0.0
# ..        ...  ...         ...             ...          ...          ...
# 166  0.520833  1.0    0.666667        0.736842     0.472803          0.0
# 163  0.187500  1.0    0.666667        0.578947     0.205021          0.0
# 94   0.333333  0.0    0.333333        0.236842     0.142259          0.0
# 339  0.520833  0.0    0.333333        0.473684     0.531381          0.0
# 410  0.645833  1.0    1.000000        0.078947     0.510460          0.0
#
#      heart rate  exercise induced  depression  ecg_0.0  ecg_1.0  ecg_2.0
# 455    0.495327               1.0    1.000000      1.0      0.0      0.0
# 546    0.401869               0.0    0.555556      0.0      1.0      0.0
# 495    0.588785               0.0    0.000000      1.0      0.0      0.0
# 577    0.700935               1.0    0.000000      0.0      0.0      1.0
# 365    0.560748               0.0    1.000000      1.0      0.0      0.0
# ..          ...               ...         ...      ...      ...      ...
# 166    0.327103               0.0    0.000000      1.0      0.0      0.0
# 163    0.803738               0.0    0.000000      1.0      0.0      0.0
# 94     0.476636               0.0    0.000000      1.0      0.0      0.0
# 339    0.635514               0.0    0.000000      0.0      1.0      0.0
# 410    0.355140               0.0    0.277778      1.0      0.0      0.0
#
# [442 rows x 12 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()
DT.fit(X_train_scaled, y_train)
pred = DT.predict(X_test_scaled)

# %%
(pred == y_test).mean()
# cross_validation
# Out:
# 0.7747747747747747

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix

# %%
acc = accuracy_score(y_test, pred)
acc
# Out:
# 0.7747747747747747

# %%
rec = recall_score(y_test, pred)
rec
# Out:
# 0.7045454545454546

# %%
pre = precision_score(y_test, pred)
pre
# Out:
# 0.7209302325581395

# %%
f1 = f1_score(y_test, pred)
f1
# Out:
# 0.7126436781609196

# %%
conf = confusion_matrix(y_test, pred)
conf
# Out:
# array([[55, 12],
#        [13, 31]])

# %%
from yellowbrick.classifier import ClassificationReport

# %%
viz = ClassificationReport(DecisionTreeClassifier())
viz.fit(X_train_scaled, y_train)
viz.score(X_train_scaled, y_train)
viz.show()
# Out:
# <Axes: title={'center': 'DecisionTreeClassifier Classification Report'}>

# %%
depth = 10
result = []
for i in range(1, depth):
    DT = DecisionTreeClassifier(max_depth =i, criterion = 'gini',
                           random_state = 2020)
    DT.fit(X_train_scaled, y_train)
    result.append([i, accuracy_score(y_train, DT.predict(X_train_scaled)), accuracy_score(y_test, DT.predict(X_test_scaled))])

# %%
result
# Out:
# [[1, 0.755656108597285, 0.8468468468468469],
#  [2, 0.7805429864253394, 0.7927927927927928],
#  [3, 0.8054298642533937, 0.8378378378378378],
#  [4, 0.834841628959276, 0.8378378378378378],
#  [5, 0.8710407239819005, 0.8198198198198198],
#  [6, 0.9276018099547512, 0.8378378378378378],
#  [7, 0.9570135746606335, 0.8198198198198198],
#  [8, 0.9683257918552036, 0.7927927927927928],
#  [9, 0.9841628959276018, 0.8198198198198198]]

# %%
depth = 10
results = []

for i in range(1, depth):
    DT = DecisionTreeClassifier(max_depth=i, criterion='gini',
                                random_state=2020)
    DT.fit(X_train_scaled, y_train)
    results.append({
        "depth": i,
        "train_acc": accuracy_score(y_train, DT.predict(X_train_scaled)),
        "test_acc": accuracy_score(y_test, DT.predict(X_test_scaled))
    })
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#    depth  train_acc  test_acc
# 0      1   0.755656  0.846847
# 1      2   0.780543  0.792793
# 2      3   0.805430  0.837838
# 3      4   0.834842  0.837838
# 4      5   0.871041  0.819820
# 5      6   0.927602  0.837838
# 6      7   0.957014  0.819820
# 7      8   0.968326  0.792793
# 8      9   0.984163  0.819820

# %%
import matplotlib.pyplot as plt

plt.plot(results_df["depth"], results_df["train_acc"], label="Train")
plt.plot(results_df["depth"], results_df["test_acc"], label="Test")
plt.xlabel("Max Depth")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
from sklearn.neural_network import MLPClassifier

# %%
MLP = MLPClassifier()
MLP.fit(X_train_scaled, y_train)
pred = MLP.predict(X_test_scaled)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
(pred == y_test).mean()
# Out:
# 0.8288288288288288

# %%
MLP = MLPClassifier(random_state= 42)
MLP.fit(X_train_scaled, y_train)
pred = MLP.predict(X_test_scaled)
(pred == y_test).mean()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.8378378378378378

# %%
accuracy_score(y_train, MLP.predict(X_train_scaled))
# Out:
# 0.8280542986425339

# %%
from sklearn.svm import SVC

# %%
SVM = SVC(random_state= 1)
SVM.fit(X_train_scaled, y_train)
pred = SVM.predict(X_test_scaled)
(pred == y_test).mean()
# Out:
# 0.8378378378378378

# %% [markdown]
# <h2>Cross-Validation </h2>

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X = data_encoded.drop('c', axis=1)   # features
y = data_encoded['c']                # target

# %%
DT = DecisionTreeClassifier(criterion = 'gini', max_depth = 4, random_state= 2000)
scores = cross_val_score(DT, X, y, cv= 5, scoring = 'accuracy')

# %%
scores
# Out:
# array([0.78378378, 0.62162162, 0.81081081, 0.81818182, 0.73636364])

# %%
scores.mean()
# Out:
# 0.7541523341523342

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(10, shuffle = True, random_state = 2021)
cross_val_score(DT, X, y, cv = kf, scoring = 'accuracy' )
# Out:
# array([0.75      , 0.83928571, 0.69642857, 0.70909091, 0.8       ,
#        0.74545455, 0.65454545, 0.76363636, 0.78181818, 0.70909091])

# %%
pred = cross_val_predict(DT, X, y, cv = 10)
confusion_matrix(y, pred)
# Out:
# array([[272,  64],
#        [ 62, 155]])

# %%
from sklearn.model_selection import GridSearchCV

# %%
DT = DecisionTreeClassifier()
param = {
    'criterion': ['gini'],
    'max_depth': [3, 4, 5, 6,7],
    'min_samples_leaf':[2,3],
    'min_samples_split': [2,3]}

# %%
GS = GridSearchCV(DT, param, cv = 5, scoring = 'accuracy')

# %%
GS.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini'], 'max_depth': [3, 4, 5, 6, 7],
#                          'min_samples_leaf': [2, 3],
#                          'min_samples_split': [2, 3]},
#              scoring='accuracy')

# %%
GS.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 3,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2}

# %%
GS.best_score_
# Out:
# 0.7813267813267812

# %%
MLP = MLPClassifier(
    hidden_layer_sizes=(100, 120 ),
    solver='sgd',
    learning_rate_init=0.004,
    learning_rate='adaptive',
   random_state=2020
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scores = cross_val_score(MLP, scaler.fit_transform(X), y, cv =5, scoring = 'accuracy')
scores.mean()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.7833251433251434

# %%
X_scaled = scaler.fit_transform(X)

# %%
param_grid = {
    'hidden_layer_sizes': [(130, 80), (100, 50)],
    'learning_rate_init': [ 0.005,0.01],
    'alpha': [0.008, 0.005],
    'activation': ['relu', 'tanh']
}

grid = GridSearchCV(MLPClassifier(max_iter=50, early_stopping=True, random_state= 2020),
                    param_grid, cv=5)
grid.fit(X_scaled, y)
print(grid.best_score_)
# Out:
# 0.8229975429975431

# %%
print(grid.best_params_)
# Out:
# {'activation': 'relu', 'alpha': 0.008, 'hidden_layer_sizes': (130, 80), 'learning_rate_init': 0.005}

# %%
svm = SVC(C=1.0, kernel='linear',  decision_function_shape='ovr', break_ties=False, random_state=2025)
scores = cross_val_score(svm, X_scaled, y, cv = 5, scoring ='accuracy')
scores.mean()
# Out:
# 0.8013759213759213

# %%
svm =SVC(random_state = 1400, class_weight ={0 :0.4, 1 : 0.6} )
param = [{'kernel': ['linear'], 'C' : [0.01, 0.1, 1, 10, 100]},
        {'kernel': ['rbf'], 'gamma': [0.01, 0.08, 0.2, 0.3],  'C' : [0.08, 0.1, 1, 10, 100]}]
GS = GridSearchCV(svm, param, cv =10, scoring = 'accuracy')

# %%
GS.fit(X_scaled,y)
# Out:
# GridSearchCV(cv=10,
#              estimator=SVC(class_weight={0: 0.4, 1: 0.6}, random_state=1400),
#              param_grid=[{'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['linear']},
#                          {'C': [0.08, 0.1, 1, 10, 100],
#                           'gamma': [0.01, 0.08, 0.2, 0.3], 'kernel': ['rbf']}],
#              scoring='accuracy')

# %%
GS.best_score_
# Out:
# 0.8125
